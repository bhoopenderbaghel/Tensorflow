# %%
import tensorflow as tf 
import numpy as np 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,Dense
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787734153.965342   16221 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1787734158.209808   16221 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1787734168.483372   16221 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Generating the synthetic Data

def generate_sequences(num_sequences,max_length,vocab_size):
    sequences = []
    labels = []
    for _ in range(num_sequences):
        length = np.random.randint(1,max_length+1)
        seq = np.random.randint(0,vocab_size,length)
        label = np.sum(seq)% 2  # 0 if sum is even, 1 if odd
        sequences.append(seq)
        labels.append(label)
    return sequences,labels

# Parameters

num_sequences = 1000
max_length = 10
vocab_size = 10

# Generate data 

sequences,labels = generate_sequences(num_sequences,max_length,vocab_size)

# %%
# Pad Sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Pad sequence to the same length 
padded_sequences = pad_sequences(sequences,maxlen = max_length,padding = 'post')

# Convert labels to numpy array
labels = np.array(labels)

# %%
# Define the model 

model = Sequential()

model.add(SimpleRNN(32,input_shape = (max_length,1)))

model.add(Dense(1,activation='sigmoid'))

# Compile the model

model.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])
# Out:
# /home/bhoopender/tensorflow/tensorflow/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Reshape input data 
X = padded_sequences.reshape((num_sequences,max_length,1))
y = labels

# Train the model
model.fit(X,y,epochs=30,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6200 - loss: 0.6530 - val_accuracy: 0.4650 - val_loss: 0.7380
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6237 - loss: 0.6512 - val_accuracy: 0.4900 - val_loss: 0.7362
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6263 - loss: 0.6494 - val_accuracy: 0.4800 - val_loss: 0.7422
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6275 - loss: 0.6487 - val_accuracy: 0.4850 - val_loss: 0.7441
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6263 - loss: 0.6451 - val_accuracy: 0.5200 - val_loss: 0.7403
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6388 - loss: 0.6455 - val_accuracy: 0.4900 - val_loss: 0.7408
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6012 - loss: 0.6477 - val_accuracy: 0.5000 - val_loss: 0.7384
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6200 - loss: 0.6456 - val_accuracy: 0.5050 - val_loss: 0.7426
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6263 - loss: 0.6425 - val_accuracy: 0.5000 - val_loss: 0.7379
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6388 - loss: 0.6442 - val_accuracy: 0.4900 - val_loss: 0.7429
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6313 - loss: 0.6411 - val_accuracy: 0.4900 - val_loss: 0.7445
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6345 - val_accuracy: 0.5300 - val_loss: 0.7455
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6237 - loss: 0.6354 - val_accuracy: 0.4950 - val_loss: 0.7465
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6475 - loss: 0.6335 - val_accuracy: 0.5050 - val_loss: 0.7416
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6500 - loss: 0.6325 - val_accuracy: 0.4950 - val_loss: 0.7517
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6413 - loss: 0.6323 - val_accuracy: 0.5000 - val_loss: 0.7412
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6513 - loss: 0.6281 - val_accuracy: 0.5000 - val_loss: 0.7501
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6500 - loss: 0.6291 - val_accuracy: 0.5000 - val_loss: 0.7464
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6375 - loss: 0.6297 - val_accuracy: 0.5200 - val_loss: 0.7589
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6525 - loss: 0.6239 - val_accuracy: 0.5100 - val_loss: 0.7508
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6363 - loss: 0.6229 - val_accuracy: 0.5250 - val_loss: 0.7472
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6325 - loss: 0.6283 - val_accuracy: 0.5250 - val_loss: 0.7523
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6500 - loss: 0.6177 - val_accuracy: 0.5100 - val_loss: 0.7552
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6450 - loss: 0.6185 - val_accuracy: 0.5350 - val_loss: 0.7505
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6637 - loss: 0.6150 - val_accuracy: 0.4700 - val_loss: 0.7565
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6662 - loss: 0.6143 - val_accuracy: 0.4850 - val_loss: 0.7613
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6650 - loss: 0.6139 - val_accuracy: 0.5050 - val_loss: 0.7542
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6587 - loss: 0.6103 - val_accuracy: 0.4800 - val_loss: 0.7618
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6538 - loss: 0.6060 - val_accuracy: 0.5450 - val_loss: 0.7675
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6800 - loss: 0.6105 - val_accuracy: 0.5150 - val_loss: 0.7504

# %%
loss,accuracy = model.evaluate(X,y)

print(f"Accuracy:{accuracy*100:.2f}%")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6480 - loss: 0.6283
# Accuracy:64.80%

# %%
# Predict on new Dataset

test_seq = np.array([[1,3,5]])
test_seq_padded = pad_sequences(test_seq,maxlen = max_length,padding='post')
test_seq_reshaped = test_seq_padded.reshape((1,max_length,1))

prediction = model.predict(test_seq_reshaped)
predicted_label  = int(prediction.round()[0][0])

print(f"Predicted Label:{'Even' if predicted_label == 0 else 'Odd'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted Label:Odd
