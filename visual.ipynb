# %%
import tensorflow as tf 
import datetime 
# load the tensorboard notebook extension 
# %load_ext tensorboard

# %%
# Load the Fashion MNIST dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# preprocess the data by normalizing the pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

model.fit(train_images, train_labels, epochs=5, validation_data=(test_images, test_labels), callbacks=[tensorboard_callback])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /home/bhoopender/tensorflow/tensorflow/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1789116916.801423   22962 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2604 MB memory:  -> device: 0, name: NVIDIA T1000, pci bus id: 0000:01:00.0, compute capability: 7.5
# Epoch 1/5
# I0000 00:00:1789116921.554956   23528 service.cc:153] XLA service 0x7e39180314c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1789116921.554973   23528 service.cc:161]   StreamExecutor [0]: NVIDIA T1000, Compute Capability 7.5 (Driver: 13.2.0; Runtime: 12.5.0; Toolkit: 12.5.0; DNN: 9.25.0)
# I0000 00:00:1789116921.846238   23528 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1789116922.182331   23528 cuda_dnn.cc:461] Loaded cuDNN version 92500
# I0000 00:00:1789116922.247224   23528 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_934__.10
#  108/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5496 - loss: 1.3146
# I0000 00:00:1789116924.199421   23528 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.8249 - loss: 0.4985 - val_accuracy: 0.8435 - val_loss: 0.4320
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8632 - loss: 0.3770 - val_accuracy: 0.8560 - val_loss: 0.4098
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8759 - loss: 0.3383 - val_accuracy: 0.8712 - val_loss: 0.3644
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8848 - loss: 0.3132 - val_accuracy: 0.8697 - val_loss: 0.3664
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8908 - loss: 0.2957 - val_accuracy: 0.8674 - val_loss: 0.3676

# %%
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-7c345723b5415d7d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7c345723b5415d7d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
file_writer = tf.summary.create_file_writer(log_dir+'/images')

# log images
with file_writer.as_default():
    images = tf.reshape(test_images[:25], [-1, 28, 28, 1])  # Reshape to (batch_size, height, width, channels)
    tf.summary.image("25 Training data examples", images, max_outputs=25, step=0)

# %%
embedding_layer = tf.keras.layers.Embedding(input_dim=10, output_dim=64)
