# %%
import tensorflow as tf 
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,GRU,Dense,Embedding

# %%
# Parameters
vocab_size = 10000
max_length = 500

# Load the IMDB dataset
(X_train,y_train),(X_test,y_test) = imdb.load_data(num_words=vocab_size)

# Pad Sequences

X_train = sequence.pad_sequences(X_train,maxlen=max_length)
X_test = sequence.pad_sequences(X_test,maxlen=max_length)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Define LSTM model
def build_lstm_model():
    model = Sequential()
    model.add(Embedding(vocab_size,128,input_length=max_length))
    model.add(LSTM(64))
    model.add(Dense(1,activation='sigmoid'))
    return model

lstm_model = build_lstm_model()
lstm_model.compile(optimizer='adam',loss = 'binary_crossentropy',metrics=['accuracy'])
# Out:
# /home/bhoopender/tensorflow/tensorflow/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1787737655.378319   26475 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2604 MB memory:  -> device: 0, name: NVIDIA T1000, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
lstm_history = lstm_model.fit(X_train,y_train,epochs=4,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/4
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9428 - loss: 0.1559 - val_accuracy: 0.8458 - val_loss: 0.4266
# Epoch 2/4
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9728 - loss: 0.0809 - val_accuracy: 0.8502 - val_loss: 0.5154
# Epoch 3/4
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9837 - loss: 0.0505 - val_accuracy: 0.8576 - val_loss: 0.5632
# Epoch 4/4
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9786 - loss: 0.0623 - val_accuracy: 0.8518 - val_loss: 0.6213

# %%
# Define the GRU model

def build_gru_model():
    model = Sequential()
    model.add(Embedding(vocab_size,128,input_length=max_length))
    model.add(GRU(64))
    model.add(Dense(1,activation='sigmoid'))
    return model

# Compile the model
gru_model = build_gru_model()
gru_model.compile(optimizer ='adam',loss = 'binary_crossentropy',metrics=['accuracy'])
# Out:
# /home/bhoopender/tensorflow/tensorflow/lib/python3.10/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
gru_history = gru_model.fit(X_train,y_train,epochs=5,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7592 - loss: 0.4784 - val_accuracy: 0.8382 - val_loss: 0.3845
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8952 - loss: 0.2634 - val_accuracy: 0.8470 - val_loss: 0.3942
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9235 - loss: 0.1986 - val_accuracy: 0.8742 - val_loss: 0.3348
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9513 - loss: 0.1362 - val_accuracy: 0.8700 - val_loss: 0.3483
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9690 - loss: 0.0923 - val_accuracy: 0.8488 - val_loss: 0.4088

# %%
# Evalute LSTM Model
lstm_loss,lstm_accuracy = lstm_model.evaluate(X_test,y_test)
print(f"LSTM TEST Accuracy:{lstm_accuracy*100:.2f}%")

# Evalute GRU Model
gru_loss,gru_accuracy = gru_model.evaluate(X_test,y_test)
print(f"GRU TEST Accuracy:{gru_accuracy*100:.2f}%")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8465 - loss: 0.6275
# LSTM TEST Accuracy:84.65%
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8462 - loss: 0.4219
# GRU TEST Accuracy:84.62%
